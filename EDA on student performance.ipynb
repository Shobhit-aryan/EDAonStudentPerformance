# %%
#importing all the required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#reading data
data = pd.read_csv(r'StudentsPerformance.csv')

# %%
#displaying first 10 data
data.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
#displaying last 10 data
data.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
#checking the number of rows and columns
data.shape
# Out:
# (1000, 8)

# %%
#describing what columns are present in the data
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#a quick statistical information on numerical data
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#a quick description on the quantity of categorical data
data.describe(include=object)
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test preparation course
# count                     1000
# unique                       2
# top                       none
# freq                       642

# %%
#information about data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# gender                         1000 non-null object
# race/ethnicity                 1000 non-null object
# parental level of education    1000 non-null object
# lunch                          1000 non-null object
# test preparation course        1000 non-null object
# math score                     1000 non-null int64
# reading score                  1000 non-null int64
# writing score                  1000 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#checking number of unique entries in each column
data.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
#checking the null values, if any, present in the data
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#checking type of unique entries in gender column
data['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
#checking type of unique entries in race/ethnicity column
data['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
#checking type of unique entries in parental level of education
data['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
#checking type of unique entries in lunch column
data['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
#checking type of unique entries in test preparation course
data['test preparation course'].unique()
# Out:
# array(['none', 'completed'], dtype=object)

# %%
#counting number of male and female students
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
#visualising number of male and female students
sns.set_style('whitegrid')
sns.countplot(x='gender', data=data)

# %%
#counting number of students of different race/ethnicity
data['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
#visualsing number of male and female students of different race/ethnicity
sns.set_style('whitegrid')
sns.countplot(x='race/ethnicity', hue='gender',data=data)

# %%
#counting number of students getting standard and free/reduced lunch services
data['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
#visualising number of male and female students recieving different lunch services
sns.set_style('whitegrid')
sns.countplot(x='lunch',hue='gender', data=data)

# %%
#counting number of students enrolled in test preparation course
data['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
#visualising number of male and female students enrolled in test preparation course
sns.set_style('whitegrid')
sns.countplot(x='test preparation course',hue='gender', data=data)

# %%
#getting percentage value
data['test preparation course'].value_counts(normalize=True)
# Out:
# none         0.642
# completed    0.358
# Name: test preparation course, dtype: float64

# %%
#counting different parental level of education
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
#visualising different parental level of education
sns.set_style('whitegrid')
sns.countplot(x='parental level of education',hue='gender' ,data=data)

# %%
#checking how parent's education affected the decision whether to enroll their child in any test preparation course
pd.crosstab(data['test preparation course'] ,data['parental level of education'], margins=True)
# Out:
# parental level of education  associate's degree  bachelor's degree  \
# test preparation course
# completed                                    82                 46
# none                                        140                 72
# All                                         222                118
#
# parental level of education  high school  master's degree  some college  \
# test preparation course
# completed                             56               20            77
# none                                 140               39           149
# All                                  196               59           226
#
# parental level of education  some high school   All
# test preparation course
# completed                                  77   358
# none                                      102   642
# All                                       179  1000

# %%
corelation = data.corr()

# %%
#visualsing the relation between the score of different subjects
sns.heatmap(corelation,xticklabels=corelation.columns, yticklabels=corelation.columns,annot=True)

# %%
#visualsing the relation between the score of different subjects
sns.pairplot(data)

# %%
sns.pairplot(data,hue='gender')

# %%
sns.pairplot(data,hue='test preparation course')

# %%
sns.pairplot(data,hue='race/ethnicity')

# %%
sns.pairplot(data,hue='lunch')

# %%
sns.distplot(data['math score'], kde =True,color='red')

# %%
sns.distplot(data['reading score'], kde =True,color='orange')

# %%
sns.distplot(data['writing score'], kde =True,color='purple')

# %%
sns.kdeplot(data['math score'], shade=True)
sns.kdeplot(data['reading score'], shade=True)
sns.kdeplot(data['writing score'], shade=True)

# %% [markdown]
# ## checking outliers

# %%
sns.boxplot(data['math score'],color='red')
Q3 = data['math score'].quantile(0.75)
Q1 = data['math score'].quantile(0.25)
IQR = Q3-Q1
print('Q1 value: ', Q1)
print('Median value: ',data['math score'].median())
print('Q3 value: ', Q3)
print('upper whisker limit: ', Q3+1.5*IQR);
print('lower whisker limit: ', Q3-1.5*IQR);
# Out:
# Q1 value:  57.0
# Median value:  66.0
# Q3 value:  77.0
# upper whisker limit:  107.0
# lower whisker limit:  47.0

# %%
sns.boxplot(data['reading score'],color='grey')
Q3 = data['reading score'].quantile(0.75)
Q1 = data['reading score'].quantile(0.25)
IQR = Q3-Q1
print('Q1 value: ', Q1)
print('Median value: ',data['reading score'].median())
print('Q3 value: ', Q3)
print('upper whisker limit: ', Q3+1.5*IQR);
print('lower whisker limit: ', Q3-1.5*IQR);
# Out:
# Q1 value:  59.0
# Median value:  70.0
# Q3 value:  79.0
# upper whisker limit:  109.0
# lower whisker limit:  49.0

# %%
sns.boxplot(data['writing score'],color = 'yellow')
Q3 = data['writing score'].quantile(0.75)
Q1 = data['writing score'].quantile(0.25)
IQR = Q3-Q1
print('Q1 value: ', Q1)
print('Median value: ',data['writing score'].median())
print('Q3 value: ', Q3)
print('upper whisker limit: ', Q3+1.5*IQR);
print('lower whisker limit: ', Q3-1.5*IQR);
# Out:
# Q1 value:  57.75
# Median value:  69.0
# Q3 value:  79.0
# upper whisker limit:  110.875
# lower whisker limit:  47.125

# %%
sns.relplot(x='math score', y='reading score',hue='gender', data=data)

# %%
sns.relplot(x='math score', y='writing score',hue='gender', data=data)

# %%
sns.relplot(x='reading score', y='writing score',hue='gender', data=data)

# %%
# !pip install plotly

# %%
import plotly.graph_objs as go
from plotly.offline import iplot

# %%
#visualising the scores in different subject using 3d plot
x=data['math score']
y=data['reading score']
z=data['writing score']
trace1 = go.Scatter3d(
    x=x,
    y=y,
    z=z,
    mode='markers',
    marker=dict(
    size=5,
    color=z,
    colorscale='emrld',
    opacity=0.8)
)

data1=[trace1]
layout=go.Layout(
    margin=dict(
    l=0,
    b=0,r=0,t=0)
    )

fig=go.Figure(data=data1, layout=layout)
iplot(fig,filename='3d score plot')
# Out:
# <div>
#
#
#             <div id="b71ed191-50e3-466e-afb6-2609c0a90349" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b71ed191-50e3-466e-afb6-2609c0a90349")) {
#                     Plotly.newPlot(
#                         'b71ed191-50e3-466e-afb6-2609c0a90349',
# ...

# %% [markdown]
# # Feature Engineering
#     Creating 4 new features from given data
#     1.Total Marks= adding math score, reading score, writing score
#     2.Result = Whether the student is passed or failed in the exam.(criteria of pass: total marks>120)
#     3.Percentage = Percentage of the student ( TOTAL MARKS/3)
#     4.Performance = How well the student has performed based on the grading system.

# %%
#adding new features i.e, total marks, result, percentage, performance
data['total marks'] = data['math score'] + data['reading score'] + data['writing score']
data['result'] = np.where(data['total marks']<120, 'F', 'P')
data['percentage'] = data['total marks']/3
data['performance'] = pd.cut(data.percentage,bins=[0,39,60,70,80,90,100],labels=['F','C','B','B+','A','A+'])
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total marks result  percentage performance
# 0          218      P   72.666667          B+
# 1          247      P   82.333333           A
# ...

# %%
#checking passing percentage between male and female students
labels = ['MALE STUDENTS PASS','FEMALE STUDENTS PASS']
sizes = [data[data.result == 'P']['gender'].value_counts()[1],
         data[data.result == 'P']['gender'].value_counts()[0]]
fig1, ax1 = plt.subplots(figsize=(20,10))
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis('equal')
plt.show()

# %% [markdown]
# Female students pass percentage is 4% higher than male students pass percentage
#
#     male students - 48.2%
#     female students - 51.8%

# %%
#Checking the passing percentage of students of different race/ethnicity
fig1, ax1 = plt.subplots(figsize=(20,10))
ax1.pie(data[data.result == 'P']['race/ethnicity'].value_counts(),explode=(.05,0.05,0,0,0),labels=['group C','group D','group B','group E','group A'],autopct='%1.1f%%',shadow=True,startangle=90)
ax1.axis('equal')
plt.show()

# %% [markdown]
# Students of group C and D have performed better than other groups student.

# %%
fig1, ax1 = plt.subplots(figsize=(20,10))
sns.countplot(data['parental level of education'],hue=data.result,ax=ax1)

# %%
degree_data = {
    'high school' :  'basic_education',
    'some high school' :  'basic_education',
    "associate's degree" : 'good education',
    "some college" : 'good education',
    "bachelor's degree" : 'high level education',
    "master's degree" : 'high level education'
}
data['parents_education'] = data['parental level of education'].map(degree_data)

# %%
fig1, ax1 = plt.subplots(figsize=(16,8))
sns.countplot(data.parents_education,ax=ax1)
sns.despine(left=True,bottom=True)
sns.set_style({'ytick.left': False,'xtick.top': False})

# %%
data[data.parents_education == 'basic_education']['result'].value_counts()
# Out:
# P    355
# F     20
# Name: result, dtype: int64

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)
ax1.pie(data[data.parents_education == 'basic_education']['result'].value_counts(),labels=['Pass','Fail'],autopct='%1.1f%%',shadow=True,startangle=90)
ax1.axis('equal')
ax1.set_title('Basic Education')
ax2.pie(data[data.parents_education == 'good education']['result'].value_counts(),labels=['Pass','Fail'],autopct='%1.1f%%',shadow=True,startangle=90)
ax2.axis('equal')
ax2.set_title('Good Education')
ax3.pie(data[data.parents_education == 'high level education']['result'].value_counts(),labels=['Pass','Fail'],autopct='%1.1f%%',shadow=True,startangle=90)
ax3.axis('equal')
ax3.set_title('High level Education')
plt.show()

# %% [markdown]
# So the students whose parents have basic education have less pass percent when compared to the parents with good and high-level education
#
#         Students of parents with basic education pass percent - 94.7%
#         Students of parents with good education pass percent - 98.2%
#         Students of parents with high-level education pass percent - 98.9%

# %%
fig1, ax1 = plt.subplots(figsize=(10,5))
sns.countplot(data.lunch,hue=data.result,ax=ax1)
sns.despine(left=True,bottom=True)
sns.set_style({'ytick.left': False,'xtick.top': False})

# %% [markdown]
# Students with free/reduced lunch might not perform well in the exam

# %%
fig1, ax1 = plt.subplots(figsize=(10,5))
sns.countplot(data['test preparation course'],ax=ax1)
sns.despine(left=True,bottom=True)
sns.set_style({'ytick.left': False,'xtick.top': False})

# %% [markdown]
# More than 50% of students didnt complete test preparation course.

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
ax1.pie(data[data['test preparation course'] == 'none']['result'].value_counts(),labels=['Pass','Fail'],autopct='%1.1f%%',shadow=True,startangle=90)
ax1.axis('equal')
ax1.set_title('Test Preperation None')
ax2.pie(data[data['test preparation course'] == 'completed']['result'].value_counts(),labels=['Pass','Fail'],autopct='%1.1f%%',shadow=True,startangle=90)
ax2.axis('equal')
ax2.set_title('Test Preperation Completed')
# Out:
# Text(0.5, 1.0, 'Test Preperation Completed')

# %% [markdown]
# The students who completed the course have more pass percentage than students who didn't complete the course.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The students with the following attribute are gonna perform better than other students
#
#         race_ethinicity: group c or group d
#         parents _education: Good education or high-level education.
#         lunch: Standard
#         test_preperation: Completed
